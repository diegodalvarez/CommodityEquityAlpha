# %% [markdown]
# # Gold Miners Equity Alpha

# %%
import os
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from   matplotlib.ticker import FuncFormatter

import statsmodels.api as sm
from   statsmodels.regression.rolling import RollingOLS

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Getting Data

# %%
alpha_path   = os.path.join(os.getcwd(), "data", "GoldMinersAlpha.parquet")
df_alpha_raw = (pd.read_parquet(
    path = alpha_path, engine = "pyarrow").
    reset_index().
    dropna())

# %%
path  = os.path.join(os.getcwd(), "data", "commod_px.parquet")
df_gc = (pd.read_parquet(
    path = path, engine = "pyarrow").
    query("security == 'GC1 Comdty'").
    assign(date = lambda x: pd.to_datetime(x.date).dt.date).
    set_index("date")
    [["PX_LAST"]].
    sort_index().
    pct_change().
    rename(columns = {"PX_LAST": "gc_rtn"}))

# %% [markdown]
# # Single exogenous variable regression

# %%
def _get_resid(df: pd.DataFrame, q: int = 10) -> pd.DataFrame: 
    
    df_tmp = df.dropna().sort_index().assign(alpha = lambda x: x.alpha.shift()).dropna()
    df_out = (sm.OLS(
        endog = df_tmp.gc_rtn,
        exog  = sm.add_constant(df_tmp.alpha)).
        fit().
        resid.
        to_frame(name = "resid").
        assign(
            lag_resid = lambda x: x.resid.shift(),
            decile    = lambda x: pd.qcut(x = x.resid, q = q, labels = [i + 1 for i in range(q)]).shift()).
        merge(right = df, how = "inner", on = ["date"]))
    
    return df_out

df_ols = (df_gc.merge(
    right = df_alpha_raw, how = "inner", on = ["date"]).
    set_index("date").
    groupby("group_var").
    apply(_get_resid, include_groups = False).
    reset_index().
    assign(signal_rtn = lambda x: -np.sign(x.lag_resid) * x.gc_rtn))

# %%
df_ols_rsk = (df_ols.pivot(
    index = "date", columns = "group_var", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) > 0.2, np.nan, x)).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(
        ticker = lambda x: x.group_var.str.split(" ").str[0],
        group  = lambda x: x.group_var.str.split(" ").str[1]).
    dropna())

# %%
groups    = df_ols.group.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(groups) // 2, nrows = len(groups) // 2, figsize = (20,10))

renamer = {
    "country"           : "Country Of Origin",
    "country_type_group": "Controlling for Developed and Developing",
    "gdx"               : "Gold Miners",
    "spy"               : "SPY"}

for group, ax in zip(groups, axes.flatten()): 
    
    (df_ols_rsk.query(
        "group == @group").
        pivot(index = "date", columns = "ticker", values = "rtn").
        apply(lambda x: np.cumprod(1 + x)).
        plot(
            logy   = True, 
            alpha  = 0.6,
            legend = False,
            ax     = ax,
            title  = renamer[group],
            xlabel = "",
            ylabel = "Cuml. Ret. Log-Scaled"))

fig.suptitle("Cumulative Returns for Trading Residuals of Regression using 10% Volatility Targeting\nFrom {} to {}".format(
    df_ols_rsk.date.min(),
    df_ols_rsk.date.max()))
# Out:
# Text(0.5, 0.98, 'Cumulative Returns for Trading Residuals of Regression using 10% Volatility Targeting\nFrom 1993-04-01 to 2026-01-12')

# %%
df_lag = (df_ols.pivot(
    index = "date", columns = "group_var", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(vol_target = "lagged"))

df_perf = (df_ols.pivot(
    index = "date", columns = "group_var", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(vol_target = "perfect"))

# %%
df_port = (pd.concat([
    df_lag, df_perf]).
    assign(
        rtn    = lambda x: np.where(np.abs(x.rtn) > 0.2, np.nan, x.rtn),
        ticker = lambda x: x.group_var.str.split(" ").str[0],
        group  = lambda x: x.group_var.str.split(" ").str[1]).
    dropna()
    [["date", "group", "rtn", "vol_target"]].
    groupby(["date", "group", "vol_target"]).
    agg("mean").
    reset_index())

# %%
replacer = {
        "gdx"               : "Gold Miners",
        "country"           : "Country\n(Origin)",
        "spy"               : "SPY",
        "country_type_group": "Developed/ing\nCountry"}

# %%
(df_port.drop(
    columns = ["date"]).
    groupby(["group", "vol_target"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    assign(vol_target = lambda x: x.vol_target.str.capitalize()).
    rename(columns = {"vol_target": ""}).
    replace(replacer).
    pivot(index = "group", columns = "", values = "rtn").
    sort_values("Lagged").
    plot(
        figsize = (8,5),
        kind    = "bar",
        xlabel  = "",
        ylabel  = "Ann. Sharpe",
        title   = "Annualized Sharpe per Each Group",
        rot     = 0))

plt.tight_layout()

# %%
groups    = df_port.vol_target.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(groups), figsize = (16,6))

vol_renamer = {}

for group, ax in zip(groups, axes.flatten()): 

    df_corr = (df_port.query(
        "vol_target == @group").
        replace(replacer).
        pivot(index = "date", columns = "group", values = "rtn").
        corr().
        apply(lambda x: np.round(x,3)))

    sns.heatmap(
        ax    = ax,
        data  = df_corr,
        annot = True,
        cbar  = False)

    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_title(group.capitalize() + " Volatility Targetting")

fig.suptitle("Correlation Matrix of Trading OLS Resids Controlling for different Factors")
plt.tight_layout()

# %% [markdown]
# # Trading Deciles of Single Exogenous Residuals

# %%
df_decile_sharpe = (df_ols[
    ["group_var", "decile", "gc_rtn"]].
    dropna().
    groupby(["group_var", "decile"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    rename(columns = {"gc_rtn": "sharpe"}))

# %%
df_tmp = (df_decile_sharpe.query(
    "decile == [1,2,9,10]").
    assign(group = lambda x: np.where(x.decile <= 2, "lgroup", "ugroup")))

# %%
df_scaler = (df_tmp.drop(
    columns = ["decile"]).
    groupby(["group_var", "group"]).
    agg("prod").
    assign(signal_scaler = lambda x: np.where(x.sharpe > 0, 1, 0)).
    drop(columns = ["sharpe"]).
    reset_index())

# %%
df_decile_rtn = (df_tmp.merge(
    right = df_scaler, how = "inner", on = ["group_var", "group"]).
    drop(columns = ["group"]).
    assign(signal = lambda x: np.sign(x.sharpe) * x.signal_scaler).
    merge(right = df_ols, how = "outer", on = ["group_var", "decile"]).
    assign(signal_rtn = lambda x: x.signal * x.gc_rtn))

# %%
df_wider = (df_decile_rtn.pivot(
    index = "date", columns = "group_var", values = "signal_rtn"))

# %%
df_lagged = (df_wider.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    dropna().
    assign(vol_target = "lagged"))

df_perf = (df_wider.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    dropna().
    assign(vol_target = "perfect"))

# %%
df_decile_rsk_rtn = (pd.concat([
    df_lagged, df_perf]).
    dropna().
    assign(
        rtn = lambda x: np.where(np.abs(x.rtn) > 0.1, np.nan, x.rtn),
        ticker = lambda x: x.group_var.str.split(" ").str[0],
        group  = lambda x: x.group_var.str.split(" ").str[1]))

# %%
df_decile_rsk_port = (df_decile_rsk_rtn[
    ["date", "vol_target", "group", "rtn"]].
    groupby(["date", "vol_target", "group"]).
    agg("mean").
    reset_index())

# %%
vol_targets = df_decile_rsk_port.vol_target.drop_duplicates().sort_values().to_list()
fig, axes   = plt.subplots(ncols = len(vol_targets), figsize = (20,6))

for vol_target, ax in zip(vol_targets, axes.flatten()):

    (df_decile_rsk_port.query(
        "vol_target == @vol_target").
        rename(columns = {"group": ""}).
        pivot(index = "date", columns = "", values = "rtn").
        rename(columns = replacer).
        fillna(0).
        apply(lambda x: np.cumprod(1 + x)).
        plot(
            logy   = True,
            ax     = ax,
            ylabel = "Cuml. Ret. Log-Scaled",
            title  = vol_target.capitalize() + " Volatility Targetting"))

fig.suptitle("Cumulative Returns of Trading Outer Deciles of OLS Regression")
plt.tight_layout()

# %%
group_vars = df_decile_rsk_port.vol_target.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (15,5))

for group_var, ax in zip(group_vars, axes.flatten()): 

    df_corr = (df_decile_rsk_port.query(
        "vol_target == @group_var").
        pivot(index = "date", columns = "group", values = "rtn").
        rename(columns = replacer).
        corr())

    sns.heatmap(
        ax    = ax,
        data  = df_corr,
        annot = True,
        cbar  = False)

    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_title(group_var.capitalize() + " Volatility Targetting")

fig.suptitle("Correlation of Returns")
plt.tight_layout()

# %%
df_decile_sharpe = (df_decile_rsk_port.rename(
    columns = {"rtn": "raw_val"}).
    assign(adj_val = lambda x: np.where(x.raw_val == 0, np.nan, x.raw_val)).
    melt(id_vars = ["date", "vol_target", "group"]).
    dropna().
    drop(columns =  ["date"]).
    groupby(["vol_target", "group", "variable"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index())

# %%
replacer = {
        "gdx"               : "Gold Miners",
        "country"           : "Country (Origin)",
        "spy"               : "SPY",
        "country_type_group": "Developed/ing Country"}

# %%
(df_decile_sharpe.replace(
    replacer).
    assign(vol_target = lambda x: x.vol_target.str.capitalize()).
    rename(columns = {
        "variable"  : "",
        "vol_target": "Vol. Target"}).
    pivot(index = ["group"], columns = ["Vol. Target", ""], values = "value").
    rename(columns = {
        "adj_val": "Adj Val",
        "raw_val": "Raw Val"}).
    apply(lambda x: np.round(x,3)))
# Out:
# Vol. Target            Lagged         Perfect
#                       Adj Val Raw Val Adj Val Raw Val
# group
# Country (Origin)        0.983   0.923   1.130   1.061
# Developed/ing Country   0.822   0.816   0.917   0.909
# Gold Miners             1.025   0.995   1.144   1.111
# SPY                     0.669   0.649   0.801   0.777

# %% [markdown]
# # Multi-Exogenous Variable Regression

# %%
path = r"data/MultiGoldMinersAlpha.parquet"

# %%
df_alpha = (pd.read_parquet(
    path = path, engine = "pyarrow")
    [["endog_ticker", "date", "alpha"]].
    dropna())

# %%
def _get_resid(df: pd.DataFrame, q: int = 10) -> pd.DataFrame: 

    df_out = (sm.OLS(
        endog = df.gc_rtn,
        exog  = sm.add_constant(df.alpha)).
        fit().
        resid.
        to_frame(name = "resid").
        assign(
            lag_resid = lambda x: x.resid.shift(),
            decile    = lambda x: pd.qcut(x = x.resid, q = 10, labels = [i + 1 for i in range(10)]).shift()).
        merge(right = df, how = "inner", on = ["date"]))

    return df_out

df_resid = (df_gc.merge(
    right = df_alpha, how = "inner", on = ["date"]).
    set_index("date").
    groupby("endog_ticker").
    apply(_get_resid, include_groups = False).
    reset_index().
    assign(signal_rtn = lambda x: -np.sign(x.lag_resid) * x.gc_rtn))

# %%
df_wider = (df_resid.pivot(
    index = "date", columns = "endog_ticker", values = "signal_rtn"))

# %%
df_lagged = (df_wider.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(vol_target = "lagged"))

df_perf = (df_wider.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(vol_target = "perfect"))

# %%
df_combined = (pd.concat([df_lagged, df_perf]))

# %%
group_vars = df_combined.vol_target.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (20,6))

for group_var, ax in zip(group_vars, axes.flatten()):

    (df_combined.query(
        "vol_target == @vol_target").
        pivot(index = "date", columns = "endog_ticker", values = "rtn").
        apply(lambda x: np.cumprod(1 + x)).
        plot(
            ax     = ax,
            logy   = True, 
            alpha  = 0.6, 
            legend = False,
            title  = group_var.capitalize() + " Volatility Targetting",
            ylabel = "Cuml. Ret. Log-Scaled",
            xlabel = ""))

fig.suptitle("Cumulative Returns of Trading Residuals of OLS Regression controlling for all Factors\nFrom {} to {}".format(
    df_combined.date.min(),
    df_combined.date.max()))

plt.tight_layout()

# %%
df_decile_sharpe = (df_resid[
    ["endog_ticker", "decile", "gc_rtn"]].
    groupby(["endog_ticker", "decile"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index())

# %%
df_decile_tmp = (df_decile_sharpe.query(
    "decile == [1,2,9,10]").
    assign(group = lambda x: np.where(x.decile <= 2, "lgroup", "ugroup")))

# %%
df_decile_rtn = (df_decile_tmp.drop(
    columns = ["decile"]).
    groupby(["endog_ticker", "group"]).
    agg("prod").
    assign(sig_scaler = lambda x: np.where(x.gc_rtn > 0, 1, np.nan)).
    reset_index().
    drop(columns = ["gc_rtn"]).
    merge(right = df_decile_tmp, how = "outer", on = ["endog_ticker", "group"]).
    rename(columns = {"gc_rtn": "sharpe"}).
    merge(right = df_resid, how = "outer", on = ["endog_ticker", "decile"]).
    assign(signal_rtn = lambda x: np.sign(x.sig_scaler  * x.sharpe) * x.gc_rtn))

# %%
df_decile_wider = (df_decile_rtn.pivot(
    index = "date", columns = "endog_ticker", values = "signal_rtn"))

df_lagged_longer = (df_decile_rtn.pivot(
    index = "date", columns = "endog_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)).
    reset_index().
    melt(id_vars = "date").
    assign(group = "lagged"))

df_perfect_longer = (df_decile_rtn.pivot(
    index = "date", columns = "endog_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)).
    reset_index().
    melt(id_vars = "date").
    assign(group = "perfect"))

# %%
df_combined = (pd.concat([
    df_lagged_longer, df_perfect_longer]).
    dropna().
    query("value != 0"))

# %%
group_vars = df_combined.group.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (20,6))

for group_var, ax in zip(group_vars, axes.flatten()): 

    (df_combined.query(
        "group == @group_var").
        pivot(index = "date", columns = "endog_ticker", values = "value").
        fillna(0).
        apply(lambda x: np.cumprod(1 + x)).
        plot(
            logy   = True, 
            legend = False,
            ax     = ax,
            title  = group_var.capitalize() + " Volatility Targetting",
            ylabel = "Cuml. Ret. Log-Scaled",
            xlabel = ""))

fig.suptitle("Cumulative Returns of Trading OLS Residuals (Deciled) With 10% Volatility Targetting\nFrom {} to {}".format(
    df_combined.date.min(),
    df_combined.date.max()))

plt.tight_layout()

# %%
df_port = (df_combined.drop(
    columns = ["endog_ticker"]).
    groupby(["date", "group"]).
    agg("mean").
    reset_index())

# %%
(df_port.assign(
    group = lambda x: x.group.str.capitalize()).
    rename(columns = {"group": ""}).
    pivot(index = "date", columns = "", values = "value").
    apply(lambda x: np.cumprod(1 + x)).
    plot(
        figsize = (8,5),
        logy    = True,
        ylabel  = "Cuml. Ret. Log-Scaled",
        title   = "Cumulative Returns of Trading OLS Residuals Deciled\n10% Volatility Target From {} to {}".format(
            df_port.date.min(),
            df_port.date.max())))

plt.tight_layout()

# %%
(df_port.rename(
    columns = {"value": "raw_rtn"}).
    assign(adj_rtn = lambda x: np.where(x.raw_rtn != 0, x.raw_rtn, np.nan)).
    melt(id_vars = ["date", "group"]).
    drop(columns = ["date"]).
    groupby(["group", "variable"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    assign(group = lambda x: x.group.str.capitalize()).
    rename(columns = {
        "variable": "",
        "group"   : "Vol. Target"}).
    pivot(index = "Vol. Target", columns = "", values = "value").
    rename(columns = {
        "adj_rtn": "Adj Sharpe",
        "raw_rtn": "Raw Sharpe"}).
    apply(lambda x: np.round(x,3)))
# Out:
#              Adj Sharpe  Raw Sharpe
# Vol. Target
# Lagged            0.604       0.604
# Perfect           0.611       0.611

# %% [markdown]
# # Extracting Principal Components of Features Space

# %% [markdown]
# The average cross-correlation of the alphas are pretty uncorrelated to begin with

# %%
fig, axes = plt.subplots(figsize = (10,5))

(df_alpha_raw.pivot(
    index = ["date", "group"], columns = "ticker", values = "alpha").
    reset_index().
    set_index("date").
    groupby("group").
    agg("corr").
    reset_index().
    rename(columns = {"ticker": "ticker1"}).
    melt(id_vars = ["group", "ticker1"]).
    query("ticker1 != ticker").
    drop(columns = ["ticker", "ticker1"]).
    dropna().
    groupby("group").
    agg("mean").
    reset_index().
    replace(renamer).
    assign(group = lambda x: x.group.str.replace("Developed", "Developed\n")).
    set_index("group").
    sort_values("value").
    plot(
        ax     = axes,
        kind   = "bar",
        rot    = 0,
        xlabel = "",
        legend = False,
        ylabel = "Correlation",
        ylim   = (0.25),
        title  = "Average Correlation across Alphas of Gold Mining Stocks controlling for different factors"))

axes.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{x:.0%}"))

# %%
def _get_pca_info(df: pd.DataFrame) -> pd.DataFrame: 

    df_prep = (df.pivot(
        index = "date", columns = "ticker", values = "alpha").
        ffill().
        fillna(0))

    df_scaled = StandardScaler().fit_transform(df_prep)
    num_pcs   = len(df_prep.columns.to_list())
    pca_model = PCA(n_components = num_pcs).fit(df_scaled)

    df_out = (pd.DataFrame({
        "exp_var_ratio": pca_model.explained_variance_ratio_}).
        reset_index().
        rename(columns = {"index": "pc"}).
        assign(pc = lambda x: x.pc + 1))

    return df_out

df_exp_var = (df_alpha_raw.groupby(
    "group").
    apply(_get_pca_info, include_groups = False).
    reset_index().
    drop(columns = ["level_1"]).
    rename(columns = {"group": ""}).
    pivot(index = "pc", columns = "", values = "exp_var_ratio"))

# %%
fig, axes = plt.subplots(ncols = 2, figsize = (16,5))

renamer = {
    "country"           : "Country Of Origin",
    "country_type_group": "Develop(ed/ing)",
    "gdx"               : "Gold Miners",
    "spy"               : "SPY"}

(df_exp_var.rename(columns = renamer).plot(
    ax    = axes[0],
    kind  = "bar",
    title = "Explained Variance Proportion of Each PC"))

(df_exp_var.cumsum().plot(
    ax    = axes[1],
    kind  = "bar",
    title = "Cumulative Explained Variance Proportion of Each PC"))

for ax in axes.flatten():
    ax.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{x:.0%}"))
    ax.set_ylabel("Proportion")

fig.suptitle("Explained Variance Ratio of Principal Components of Equity Alphas")
plt.tight_layout()

# %%
def _get_fitted_pc(df: pd.DataFrame, num_pc: int) -> pd.DataFrame: 

    df_prep = (df.pivot(
        index = "date", columns = "ticker", values = "alpha").
        ffill().
        fillna(0))

    df_scaled = StandardScaler().fit_transform(df_prep)
    pca_model = PCA(n_components = num_pc).fit_transform(df_scaled)

    df_out = (pd.DataFrame(
        data    = pca_model,
        index   = df_prep.index,
        columns = ["PC{}".format(i + 1) for i in range(num_pc)]).
        reset_index().
        melt(id_vars = "date", value_name = "pc_val"))

    return df_out

num_pc       = 24
df_fitted_pc = (df_alpha_raw.groupby(
    "group").
    apply(_get_fitted_pc, num_pc, include_groups = False).
    reset_index().
    drop(columns = ["level_1"]))

# %%
df_combined = (df_fitted_pc.pivot(
    index = ["date", "group"], columns = "variable", values = "pc_val").
    reset_index().
    merge(right = df_gc, how = "inner", on = ["date"]).
    set_index("date"))

# %%
def _get_resid(df: pd.DataFrame, q: int = 10) -> pd.DataFrame: 

    exog_cols = [col for col in df.columns.to_list() if col[0:2] == "PC"]
    df_tmp    = (df.reset_index().set_index([
        "date", "gc_rtn"]).
        shift().
        dropna().
        reset_index().
        set_index("date"))

    df_out    = (sm.OLS(
        endog = df_tmp.gc_rtn,
        exog  = sm.add_constant(df_tmp[exog_cols])).
        fit().
        resid.
        to_frame(name = "resid").
        assign(
            lag_resid = lambda x: x.resid.shift(),
            decile    = lambda x: pd.qcut(x = x.resid, q = 10, labels = range(1, q + 1)).shift()).
        merge(right = df, how = "inner", on = ["date"])
        [["resid", "lag_resid", "decile", "gc_rtn"]])

    return df_out

df_resid = (df_combined.groupby(
    "group").
    apply(_get_resid, include_groups = False).
    reset_index())

# %%
df_decile_sharpe = (df_resid[
    ["group", "decile", "gc_rtn"]].
    dropna().
    groupby(["group", "decile"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    rename(columns = {"gc_rtn": "sharpe"}).
    reset_index())

# %%
df_decile_tmp = (df_decile_sharpe.query(
    "decile == [1,2,9,10]").
    assign(group_var = lambda x: np.where(x.decile <= 2, "lgroup", "ugroup")))

# %%
df_wider = (df_decile_tmp.drop(
    columns = ["decile"]).
    groupby(["group", "group_var"]).
    agg("prod").
    assign(signal_scaler = lambda x: np.where(x.sharpe > 0, 1, np.nan)).
    drop(columns = ["sharpe"]).
    reset_index().
    merge(right = df_decile_tmp, how = "outer", on = ["group", "group_var"]).
    merge(right = df_resid, how = "outer", on = ["group", "decile"]).
    assign(signal_rtn = lambda x: np.sign(x.signal_scaler * x.sharpe) * x.gc_rtn).
    pivot(index = "date", columns = "group", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)))

# %%
(df_wider.fillna(0).
    apply(lambda x: np.cumprod(1 + x)).
    plot(logy = True))
# Out:
# <Axes: xlabel='date'>

# %%
(df_wider.agg(lambda x: x.mean() / x.std() * np.sqrt(252)))
# Out:
# group
# country               0.904175
# country_type_group    1.093356
# gdx                   1.113183
# spy                   0.767458
# dtype: float64

# %%
(df_wider.reset_index().melt(
    id_vars = "date").
    dropna().
    drop(columns = ["date"]).
    groupby("group").
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)))
# Out:
#                        value
# group
# country             0.904175
# country_type_group  1.093356
# gdx                 1.113183
# spy                 0.767458

# %%
def _get_resid(df: pd.DataFrame, q: int = 10) -> pd.DataFrame: 

    df_tmp = (df.assign(
        value = lambda x: x.value.shift()).
        dropna())

    df_out = (sm.OLS(
        endog = df_tmp.gc_rtn,
        exog  = sm.add_constant(df_tmp.value)).
        fit().
        resid.
        to_frame(name = "resid").
        assign(
            decile    = lambda x: pd.qcut(x = x.resid, q = 10, labels = range(1,11)).shift(),
            lag_resid = lambda x: x.resid.shift()).
        merge(right = df_tmp, how = "inner", on = ["date"]))

    return df_out

df_resid = (df_combined.reset_index().melt(
    id_vars = ["date", "group", "gc_rtn"]).
    assign(group_var = lambda x: x.group + " " + x.variable).
    set_index("date").
    groupby("group_var").
    apply(_get_resid).
    reset_index())

# %%
df_decile_sharpe = (df_resid[
    ["group_var", "decile", "gc_rtn"]].
    dropna().
    groupby(["group_var", "decile"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    rename(columns = {"gc_rtn": "sharpe"}))

# %%
df_decile_tmp = (df_decile_sharpe.query(
    "decile == [1,2,9,10]").
    assign(dec_group = lambda x: np.where(x.decile <= 2, "lgroup", "ugroup")))

# %%
df_tmp = (df_decile_tmp.drop(
    columns = ["decile"]).
    groupby(["group_var", "dec_group"]).
    agg("prod").
    assign(signal_scaler = lambda x: np.where(x.sharpe > 0, 1, np.nan)).
    reset_index().
    drop(columns = ["sharpe"]).
    merge(right = df_decile_tmp, how = "outer", on = ["group_var", "dec_group"]).
    merge(right = df_resid, how = "outer", on = ["decile", "group_var"]))

# %%
df_wider = (df_tmp.assign(
    signal_rtn = lambda x: np.sign(x.signal_scaler * x.sharpe) * x.gc_rtn)
    [["date", "group", "signal_rtn", "variable"]].
    pivot(index = "date", columns = ["group", "variable"], values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)).
    reset_index().
    melt(id_vars = [("date", "")]).
    rename(columns = {("date", ""): "date"}).
    drop(columns = ["variable"]).
    groupby(["date", "group"]).
    agg("mean").
    reset_index().
    pivot(index = "date", columns = "group", values = "value"))

# %%
(df_wider.
    fillna(0).
    apply(lambda x: np.cumprod(1 + x)).
    plot(logy = True))
# Out:
# <Axes: xlabel='date'>

# %%
df_wider.agg(lambda x: x.mean() / x.std() * np.sqrt(252))
# Out:
# group
# country               0.894252
# country_type_group    0.957220
# gdx                   1.065746
# spy                   0.764665
# dtype: float64
